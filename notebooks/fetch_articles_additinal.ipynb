# %%
import sys
import os

if 'root_dir' not in globals():
    # rootディレクトリへのパスを設定
    root_dir = os.path.abspath(os.path.join(os.getcwd(), '../'))
    os.chdir(root_dir)

# %%
query = 'ラムネ味わらび餅'

# %% [markdown]
# # 記事を取得する

# %%
# 自作したコードをimportする
from my_codes import fetch_articles

# %%
query_keys_all_df, selected_all_user_data = fetch_articles.main(
    query = query, size=100, batches=10000,interval=1
)

# %% [markdown]
# # 前処理をする

# %%
from my_codes import preprocessing

# %%
preprocessing.main(query=query)
# Out:
# /Users/tomokitobimatsu/github/note_analysis/my_codes/preprocessing.py:67: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "html.parser").get_text()
#             id  user_id     status      type            key  \
# 0     46658750  2834155  published  TextNote  neeb262cd4cd6
# 1     84856314  2834155  published  TextNote  nc3868e50774d
# 2     86485431  2834155  published  TextNote  n7b2110dc9a8b
# 3     86425167  2834155  published  TextNote  n00a7f36f45bd
# 4     86360142  2834155  published  TextNote  n9c98cb0478f6
# ...        ...      ...        ...       ...            ...
# 1720  40441682  3476539  published  TalkNote  n0b70cd4e6856
# 1721  39576424  3476539  published  TalkNote  n7a50a6235dfd
# 1722  39328709  3476539  published  TalkNote  n78af980f7d4c
# 1723  39281466  3476539  published  TalkNote  n02c8f7a90a4c
# 1724  19613981  3476539  published  TalkNote  n85b082b712a0
#
#                     slug                                               name  \
# 0     slug-neeb262cd4cd6                                        私のコンテンツあれこれ
# 1     slug-nc3868e50774d                            ミートスライサーで職場の人をビビらせてしまった
# 2     slug-n7b2110dc9a8b                                             風邪ひいてた
# 3     slug-n00a7f36f45bd  ドラゴンクエストスペシャルコンサートに行ってきました。すぎやまこういち氏作曲の“交響組曲「ド...
# 4     slug-n9c98cb0478f6                            Aぇǃgroup、デビューおめでとうございます
# ...                  ...                                                ...
# 1720  slug-n0b70cd4e6856                                                NaN
# 1721  slug-n7a50a6235dfd                                                NaN
# 1722  slug-n78af980f7d4c                                                NaN
# 1723  slug-n02c8f7a90a4c                                                NaN
# 1724  slug-n85b082b712a0                                                NaN
#
#                                                    body  \
# 0     ご覧いただきありがとうございます。私は小説家になろう、とノベルアッププラスで小説を書いていま...
# 1     ミートスライサーで職場の人をビビらせてしまったお疲れ様です。今日は職場でミートスライサーを使...
# 2     風邪ひいてたお疲れ様です。寝てました。昨日夜中にちょっと暑いな、と思っていたら熱が出ていたよ...
# 3     お疲れ様です! 今日は、ドラゴンクエストスペシャルコンサートに行ってきました。すぎやまこうい...
# 4     お疲れ様です。今日は店で唐揚げ上げたり、丼作ったり、盛り付け習ったりしました。つけ麺の麺を、...
# ...                                                 ...
# 1720  笑い声が大きすぎる人 手を叩いて笑う人 何かを聞かれても黙り込む人 Instagramの勉強...
# 1721                            青空文庫耕作員になって横溝正史の作品を入力する
# 1722                    おばあちゃん家行った、雰囲気がいい感じなレストラン行く約束した
# 1723                                ひややっこをわさび醤油で食べるとうまい
# 1724      Twitter代わりに 願望と羨望と嫌悪の垂れ流し 兎死狗烹 蟷螂之斧 呉牛喘月 狂言綺語
#
#                          created_at  can_read  \
# 0     2022-04-02T00:36:38.000+09:00      True
